# %%
import torch
import torchvision
import torch.optim as optim
from data.data import get_train_test_loader
from model.network import FastUpdateNet_CNet, TeacherNet
import torch.nn.functional as F
import time
import pickle

# %%
n_epochs = 100
batch_size_train = 64
batch_size_test = 1000
learning_rate = 0.0005
momentum = 0.5
log_interval = 10

random_seed = 1
torch.backends.cudnn.enabled = False
# torch.manual_seed(random_seed)

# %%
train_loader, test_loader = get_train_test_loader('mnist')

# %%
train_losses = []
train_counter = []
test_losses = []
test_accuracies = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
from threading import Thread

def do(network):
  network.mNet.backwardHidden() 

def train_fastNet(epoch, network):
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    optimizer.zero_grad()
    output = network(data)
    loss = F.nll_loss(output, target)
    loss.backward()
    network.cNet.backwardHidden() 
    network.cNet.train_c()
    correctness = (target == torch.argmax(output))
    optimizer.step()
    if batch_idx % log_interval == 0:
      train_losses.append(loss.item())
      train_counter.append(
        (batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))


def train_teacherNet(epoch, network):
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    optimizer.zero_grad()
    output = network(data)
    loss = F.nll_loss(output, target)
    loss.backward()
    # print(network.mNet.saver.grad)
    correctness = (target == torch.argmax(output))
    optimizer.step()
    if batch_idx % log_interval == 0:
      train_losses.append(loss.item())
      train_counter.append(
        (batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))

# %%
def test(network):
  network.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      output = network(data)
      test_loss += F.nll_loss(output, target, size_average=False).item()
      pred = output.data.max(1, keepdim=True)[1]
      correct += pred.eq(target.data.view_as(pred)).sum()
  test_loss /= len(test_loader.dataset)
  test_losses.append(test_loss)
  test_accuracies.append(100. * correct / len(test_loader.dataset))
  print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))

# %% [markdown]
# with inv
# error tensor(0.0003, grad_fn=<SumBackward0>)
# 0.018805503845214844
#
# with pinv
# error tensor(0.00004, grad_fn=<SumBackward0>)
# 0.02195906639099121
#
# 0.01661086082458496

# %%
train_losses = []
train_counter = []
test_losses = []
test_accuracies = []

cNet = FastUpdateNet_CNet()
optimizer = optim.SGD(cNet.get_parameters(), lr=learning_rate, momentum=momentum)
test(cNet)
for epoch in range(1, n_epochs + 1):
  train_fastNet(epoch, cNet)
  test(cNet)
  if test_accuracies[-1] > 0.1:
    cNet.cNet.useC = True
# Out:
# /home/hao/Documents/magic-m/model/network.py:327: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(o_4)
# /home/hao/miniconda/lib/python3.8/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 2.3040, Accuracy: 1009/10000 (10%)
#
#
# Test set: Avg. loss: 2.2988, Accuracy: 1009/10000 (10%)
#
#
# Test set: Avg. loss: 2.2933, Accuracy: 1699/10000 (17%)
#
#
# Test set: Avg. loss: 2.2870, Accuracy: 1994/10000 (20%)
#
#
# Test set: Avg. loss: 2.2789, Accuracy: 2026/10000 (20%)
#
#
# Test set: Avg. loss: 2.2671, Accuracy: 2377/10000 (24%)
#
#
# Test set: Avg. loss: 2.2480, Accuracy: 2676/10000 (27%)
#
#
# Test set: Avg. loss: 2.2129, Accuracy: 2741/10000 (27%)
#
#
# Test set: Avg. loss: 2.1389, Accuracy: 2790/10000 (28%)
#
#
# Test set: Avg. loss: 1.9770, Accuracy: 2948/10000 (29%)
#
#
# Test set: Avg. loss: 1.7186, Accuracy: 3738/10000 (37%)
#
#
# Test set: Avg. loss: 1.3601, Accuracy: 5444/10000 (54%)
#
#
# Test set: Avg. loss: 1.0746, Accuracy: 6528/10000 (65%)
#
#
# Test set: Avg. loss: 0.8885, Accuracy: 7139/10000 (71%)
#
#
# Test set: Avg. loss: 0.7574, Accuracy: 7554/10000 (76%)
#
#
# Test set: Avg. loss: 0.6732, Accuracy: 7881/10000 (79%)
#
#
# Test set: Avg. loss: 0.6177, Accuracy: 8036/10000 (80%)
#
#
# Test set: Avg. loss: 0.5794, Accuracy: 8204/10000 (82%)
#
#
# Test set: Avg. loss: 0.5456, Accuracy: 8315/10000 (83%)
#
#
# Test set: Avg. loss: 0.5195, Accuracy: 8443/10000 (84%)
#
#
# Test set: Avg. loss: 0.4926, Accuracy: 8519/10000 (85%)
#
#
# Test set: Avg. loss: 0.4710, Accuracy: 8592/10000 (86%)
#
#
# Test set: Avg. loss: 0.4518, Accuracy: 8649/10000 (86%)
#
#
# Test set: Avg. loss: 0.4342, Accuracy: 8719/10000 (87%)
#
#
# Test set: Avg. loss: 0.4157, Accuracy: 8772/10000 (88%)
#
#
# Test set: Avg. loss: 0.4004, Accuracy: 8819/10000 (88%)
#
#
# Test set: Avg. loss: 0.3834, Accuracy: 8866/10000 (89%)
#
#
# Test set: Avg. loss: 0.3739, Accuracy: 8889/10000 (89%)
#
#
# Test set: Avg. loss: 0.3608, Accuracy: 8932/10000 (89%)
#
#
# Test set: Avg. loss: 0.3465, Accuracy: 8979/10000 (90%)
#
#
# Test set: Avg. loss: 0.3354, Accuracy: 9006/10000 (90%)
#
#
# Test set: Avg. loss: 0.3243, Accuracy: 9028/10000 (90%)
#
#
# Test set: Avg. loss: 0.3128, Accuracy: 9078/10000 (91%)
#
#
# Test set: Avg. loss: 0.3020, Accuracy: 9114/10000 (91%)
#
#
# Test set: Avg. loss: 0.2908, Accuracy: 9130/10000 (91%)
#
#
# Test set: Avg. loss: 0.2848, Accuracy: 9165/10000 (92%)
#
#
# Test set: Avg. loss: 0.2753, Accuracy: 9161/10000 (92%)
#
#
# Test set: Avg. loss: 0.2671, Accuracy: 9191/10000 (92%)
#
#
# Test set: Avg. loss: 0.2591, Accuracy: 9226/10000 (92%)
#
#
# Test set: Avg. loss: 0.2530, Accuracy: 9242/10000 (92%)
#
#
# Test set: Avg. loss: 0.2466, Accuracy: 9260/10000 (93%)
#
#
# Test set: Avg. loss: 0.2399, Accuracy: 9281/10000 (93%)
#
#
# Test set: Avg. loss: 0.2344, Accuracy: 9292/10000 (93%)
#
#
# Test set: Avg. loss: 0.2294, Accuracy: 9309/10000 (93%)
#
#
# Test set: Avg. loss: 0.2248, Accuracy: 9336/10000 (93%)
#
#
# Test set: Avg. loss: 0.2212, Accuracy: 9331/10000 (93%)
#
#
# Test set: Avg. loss: 0.2159, Accuracy: 9355/10000 (94%)
#
#
# Test set: Avg. loss: 0.2121, Accuracy: 9368/10000 (94%)
#
#
# Test set: Avg. loss: 0.2077, Accuracy: 9370/10000 (94%)
#
#
# Test set: Avg. loss: 0.2027, Accuracy: 9381/10000 (94%)
#
#
# Test set: Avg. loss: 0.1990, Accuracy: 9394/10000 (94%)
#
#
# Test set: Avg. loss: 0.1973, Accuracy: 9405/10000 (94%)
#
#
# Test set: Avg. loss: 0.1928, Accuracy: 9409/10000 (94%)
#
#
# Test set: Avg. loss: 0.1912, Accuracy: 9408/10000 (94%)
#
#
# Test set: Avg. loss: 0.1869, Accuracy: 9424/10000 (94%)
#
#
# Test set: Avg. loss: 0.1843, Accuracy: 9437/10000 (94%)
#
#
# Test set: Avg. loss: 0.1809, Accuracy: 9439/10000 (94%)
#
#
# Test set: Avg. loss: 0.1778, Accuracy: 9453/10000 (95%)
#
#
# Test set: Avg. loss: 0.1741, Accuracy: 9467/10000 (95%)
#
#
# Test set: Avg. loss: 0.1722, Accuracy: 9484/10000 (95%)
#
#
# Test set: Avg. loss: 0.1681, Accuracy: 9481/10000 (95%)
#
#
# Test set: Avg. loss: 0.1675, Accuracy: 9486/10000 (95%)
#
#
# Test set: Avg. loss: 0.1660, Accuracy: 9500/10000 (95%)
#
#
# Test set: Avg. loss: 0.1621, Accuracy: 9504/10000 (95%)
#
#
# Test set: Avg. loss: 0.1593, Accuracy: 9513/10000 (95%)
#
#
# Test set: Avg. loss: 0.1593, Accuracy: 9518/10000 (95%)
#
#
# Test set: Avg. loss: 0.1583, Accuracy: 9517/10000 (95%)
#
#
# Test set: Avg. loss: 0.1558, Accuracy: 9524/10000 (95%)
#
#
# Test set: Avg. loss: 0.1543, Accuracy: 9529/10000 (95%)
#
#
# Test set: Avg. loss: 0.1519, Accuracy: 9535/10000 (95%)
#
#
# Test set: Avg. loss: 0.1495, Accuracy: 9550/10000 (96%)
#
#
# Test set: Avg. loss: 0.1473, Accuracy: 9553/10000 (96%)
#
#
# Test set: Avg. loss: 0.1467, Accuracy: 9556/10000 (96%)
#
#
# Test set: Avg. loss: 0.1456, Accuracy: 9565/10000 (96%)
#
#
# Test set: Avg. loss: 0.1455, Accuracy: 9569/10000 (96%)
#
#
# Test set: Avg. loss: 0.1432, Accuracy: 9567/10000 (96%)
#
#
# Test set: Avg. loss: 0.1427, Accuracy: 9574/10000 (96%)
#
#
# Test set: Avg. loss: 0.1403, Accuracy: 9578/10000 (96%)
#
#
# Test set: Avg. loss: 0.1375, Accuracy: 9580/10000 (96%)
#
#
# Test set: Avg. loss: 0.1360, Accuracy: 9577/10000 (96%)
#
#
# Test set: Avg. loss: 0.1346, Accuracy: 9584/10000 (96%)
#
#
# Test set: Avg. loss: 0.1338, Accuracy: 9595/10000 (96%)
#
#
# Test set: Avg. loss: 0.1322, Accuracy: 9596/10000 (96%)
#
#
# Test set: Avg. loss: 0.1327, Accuracy: 9600/10000 (96%)
#
#
# Test set: Avg. loss: 0.1309, Accuracy: 9596/10000 (96%)
#
#
# Test set: Avg. loss: 0.1295, Accuracy: 9599/10000 (96%)
#
#
# Test set: Avg. loss: 0.1283, Accuracy: 9607/10000 (96%)
#
#
# Test set: Avg. loss: 0.1269, Accuracy: 9613/10000 (96%)
#
#
# Test set: Avg. loss: 0.1254, Accuracy: 9618/10000 (96%)
#
#
# Test set: Avg. loss: 0.1247, Accuracy: 9624/10000 (96%)
#
#
# Test set: Avg. loss: 0.1247, Accuracy: 9626/10000 (96%)
#
#
# Test set: Avg. loss: 0.1254, Accuracy: 9618/10000 (96%)
#
#
# Test set: Avg. loss: 0.1227, Accuracy: 9624/10000 (96%)
#
#
# Test set: Avg. loss: 0.1214, Accuracy: 9630/10000 (96%)
#
#
# Test set: Avg. loss: 0.1210, Accuracy: 9630/10000 (96%)
#
#
# Test set: Avg. loss: 0.1187, Accuracy: 9629/10000 (96%)
#
#
# Test set: Avg. loss: 0.1175, Accuracy: 9647/10000 (96%)
#
#
# Test set: Avg. loss: 0.1161, Accuracy: 9645/10000 (96%)
#
#
# Test set: Avg. loss: 0.1150, Accuracy: 9654/10000 (97%)
#
#
# Test set: Avg. loss: 0.1149, Accuracy: 9652/10000 (97%)
#
#
# Test set: Avg. loss: 0.1158, Accuracy: 9649/10000 (96%)

# %%
train_losses = []
train_counter = []
test_losses = []
test_accuracies = []

cNet = FastUpdateNet_CNet()
optimizer = optim.SGD(cNet.get_parameters(), lr=learning_rate, momentum=momentum)
test(cNet)
for epoch in range(1, n_epochs + 1):
  train_fastNet(epoch, cNet)
  test(cNet)
  if test_accuracies[-1] > 0.5:
    cNet.cNet.useC = True
# Out:
# Test set: Avg. loss: 2.3033, Accuracy: 1009/10000 (10%)
#
#
# Test set: Avg. loss: 2.2972, Accuracy: 1048/10000 (10%)
#
#
# Test set: Avg. loss: 2.2905, Accuracy: 1467/10000 (15%)
#
#
# Test set: Avg. loss: 2.2814, Accuracy: 2481/10000 (25%)
#
#
# Test set: Avg. loss: 2.2674, Accuracy: 3329/10000 (33%)
#
#
# Test set: Avg. loss: 2.2426, Accuracy: 3492/10000 (35%)
#
#
# Test set: Avg. loss: 2.1924, Accuracy: 3203/10000 (32%)
#
#
# Test set: Avg. loss: 2.0825, Accuracy: 2952/10000 (30%)
#
#
# Test set: Avg. loss: 1.8891, Accuracy: 3565/10000 (36%)
#
#
# Test set: Avg. loss: 1.5716, Accuracy: 4900/10000 (49%)
#
#
# Test set: Avg. loss: 1.2268, Accuracy: 6138/10000 (61%)
#
#
# Test set: Avg. loss: 0.9840, Accuracy: 7049/10000 (70%)
#
#
# Test set: Avg. loss: 0.8057, Accuracy: 7607/10000 (76%)
#
#
# Test set: Avg. loss: 0.6615, Accuracy: 8059/10000 (81%)
#
#
# Test set: Avg. loss: 0.5668, Accuracy: 8343/10000 (83%)
#
#
# Test set: Avg. loss: 0.5103, Accuracy: 8504/10000 (85%)
#
#
# Test set: Avg. loss: 0.4737, Accuracy: 8615/10000 (86%)
#
#
# Test set: Avg. loss: 0.4449, Accuracy: 8701/10000 (87%)
#
#
# Test set: Avg. loss: 0.4246, Accuracy: 8732/10000 (87%)
#
#
# Test set: Avg. loss: 0.4041, Accuracy: 8812/10000 (88%)
#
#
# Test set: Avg. loss: 0.3908, Accuracy: 8833/10000 (88%)
#
#
# Test set: Avg. loss: 0.3740, Accuracy: 8895/10000 (89%)
#
#
# Test set: Avg. loss: 0.3618, Accuracy: 8943/10000 (89%)
#
#
# Test set: Avg. loss: 0.3499, Accuracy: 8972/10000 (90%)
#
#
# Test set: Avg. loss: 0.3381, Accuracy: 9017/10000 (90%)
#
#
# Test set: Avg. loss: 0.3287, Accuracy: 9034/10000 (90%)
#
#
# Test set: Avg. loss: 0.3194, Accuracy: 9034/10000 (90%)
#
#
# Test set: Avg. loss: 0.3074, Accuracy: 9105/10000 (91%)
#
#
# Test set: Avg. loss: 0.2998, Accuracy: 9106/10000 (91%)
#
#
# Test set: Avg. loss: 0.2903, Accuracy: 9139/10000 (91%)
#
#
# Test set: Avg. loss: 0.2826, Accuracy: 9167/10000 (92%)
#
#
# Test set: Avg. loss: 0.2761, Accuracy: 9177/10000 (92%)
#
#
# Test set: Avg. loss: 0.2675, Accuracy: 9211/10000 (92%)
#
#
# Test set: Avg. loss: 0.2599, Accuracy: 9239/10000 (92%)
#
#
# Test set: Avg. loss: 0.2535, Accuracy: 9267/10000 (93%)
#
#
# Test set: Avg. loss: 0.2457, Accuracy: 9290/10000 (93%)
#
#
# Test set: Avg. loss: 0.2421, Accuracy: 9296/10000 (93%)
#
#
# Test set: Avg. loss: 0.2351, Accuracy: 9324/10000 (93%)
#
#
# Test set: Avg. loss: 0.2285, Accuracy: 9341/10000 (93%)
#
#
# Test set: Avg. loss: 0.2235, Accuracy: 9343/10000 (93%)
#
#
# Test set: Avg. loss: 0.2168, Accuracy: 9371/10000 (94%)
#
#
# Test set: Avg. loss: 0.2121, Accuracy: 9375/10000 (94%)
#
#
# Test set: Avg. loss: 0.2071, Accuracy: 9391/10000 (94%)
#
#
# Test set: Avg. loss: 0.2033, Accuracy: 9395/10000 (94%)
#
#
# Test set: Avg. loss: 0.1994, Accuracy: 9417/10000 (94%)
#
#
# Test set: Avg. loss: 0.1965, Accuracy: 9426/10000 (94%)
#
#
# Test set: Avg. loss: 0.1924, Accuracy: 9445/10000 (94%)
#
#
# Test set: Avg. loss: 0.1897, Accuracy: 9441/10000 (94%)
#
#
# Test set: Avg. loss: 0.1862, Accuracy: 9446/10000 (94%)
#
#
# Test set: Avg. loss: 0.1814, Accuracy: 9456/10000 (95%)
#
#
# Test set: Avg. loss: 0.1757, Accuracy: 9472/10000 (95%)
#
#
# Test set: Avg. loss: 0.1723, Accuracy: 9477/10000 (95%)
#
#
# Test set: Avg. loss: 0.1707, Accuracy: 9484/10000 (95%)
#
#
# Test set: Avg. loss: 0.1678, Accuracy: 9504/10000 (95%)
#
#
# Test set: Avg. loss: 0.1656, Accuracy: 9505/10000 (95%)
#
#
# Test set: Avg. loss: 0.1623, Accuracy: 9516/10000 (95%)
#
#
# Test set: Avg. loss: 0.1601, Accuracy: 9512/10000 (95%)
#
#
# Test set: Avg. loss: 0.1584, Accuracy: 9518/10000 (95%)
#
#
# Test set: Avg. loss: 0.1564, Accuracy: 9537/10000 (95%)
#
#
# Test set: Avg. loss: 0.1543, Accuracy: 9541/10000 (95%)
#
#
# Test set: Avg. loss: 0.1515, Accuracy: 9532/10000 (95%)
#
#
# Test set: Avg. loss: 0.1489, Accuracy: 9538/10000 (95%)
#
#
# Test set: Avg. loss: 0.1467, Accuracy: 9548/10000 (95%)
#
#
# Test set: Avg. loss: 0.1445, Accuracy: 9555/10000 (96%)
#
#
# Test set: Avg. loss: 0.1434, Accuracy: 9566/10000 (96%)
#
#
# Test set: Avg. loss: 0.1422, Accuracy: 9573/10000 (96%)
#
#
# Test set: Avg. loss: 0.1399, Accuracy: 9567/10000 (96%)
#
#
# Test set: Avg. loss: 0.1377, Accuracy: 9575/10000 (96%)
#
#
# Test set: Avg. loss: 0.1353, Accuracy: 9585/10000 (96%)
#
#
# Test set: Avg. loss: 0.1333, Accuracy: 9589/10000 (96%)
#
#
# Test set: Avg. loss: 0.1317, Accuracy: 9601/10000 (96%)
#
#
# Test set: Avg. loss: 0.1311, Accuracy: 9602/10000 (96%)
#
#
# Test set: Avg. loss: 0.1309, Accuracy: 9591/10000 (96%)
#
#
# Test set: Avg. loss: 0.1297, Accuracy: 9608/10000 (96%)
#
#
# Test set: Avg. loss: 0.1280, Accuracy: 9603/10000 (96%)
#
#
# Test set: Avg. loss: 0.1270, Accuracy: 9614/10000 (96%)
#
#
# Test set: Avg. loss: 0.1255, Accuracy: 9614/10000 (96%)
#
#
# Test set: Avg. loss: 0.1243, Accuracy: 9611/10000 (96%)
#
#
# Test set: Avg. loss: 0.1225, Accuracy: 9633/10000 (96%)
#
#
# Test set: Avg. loss: 0.1213, Accuracy: 9635/10000 (96%)
#
#
# Test set: Avg. loss: 0.1196, Accuracy: 9636/10000 (96%)
#
#
# Test set: Avg. loss: 0.1186, Accuracy: 9634/10000 (96%)
#
#
# Test set: Avg. loss: 0.1182, Accuracy: 9632/10000 (96%)
#
#
# Test set: Avg. loss: 0.1165, Accuracy: 9639/10000 (96%)
#
#
# Test set: Avg. loss: 0.1164, Accuracy: 9639/10000 (96%)
#
#
# Test set: Avg. loss: 0.1151, Accuracy: 9651/10000 (97%)
#
#
# Test set: Avg. loss: 0.1146, Accuracy: 9640/10000 (96%)
#
#
# Test set: Avg. loss: 0.1138, Accuracy: 9643/10000 (96%)
#
#
# Test set: Avg. loss: 0.1139, Accuracy: 9644/10000 (96%)
#
#
# Test set: Avg. loss: 0.1142, Accuracy: 9652/10000 (97%)
#
#
# Test set: Avg. loss: 0.1128, Accuracy: 9646/10000 (96%)
#
#
# Test set: Avg. loss: 0.1114, Accuracy: 9646/10000 (96%)
#
#
# Test set: Avg. loss: 0.1097, Accuracy: 9658/10000 (97%)
#
#
# Test set: Avg. loss: 0.1088, Accuracy: 9661/10000 (97%)
#
#
# Test set: Avg. loss: 0.1088, Accuracy: 9661/10000 (97%)
#
#
# Test set: Avg. loss: 0.1082, Accuracy: 9669/10000 (97%)
#
#
# Test set: Avg. loss: 0.1095, Accuracy: 9664/10000 (97%)
#
#
# Test set: Avg. loss: 0.1069, Accuracy: 9669/10000 (97%)
#
#
# Test set: Avg. loss: 0.1064, Accuracy: 9677/10000 (97%)
#
#
# Test set: Avg. loss: 0.1053, Accuracy: 9677/10000 (97%)
#
#
# Test set: Avg. loss: 0.1035, Accuracy: 9680/10000 (97%)

# %%
train_losses = []
train_counter = []
test_losses = []
test_accuracies = []

cNet = FastUpdateNet_CNet()
optimizer = optim.SGD(cNet.get_parameters(), lr=learning_rate, momentum=momentum)
test(cNet)
for epoch in range(1, n_epochs + 1):
  train_fastNet(epoch, cNet)
  test(cNet)
  if test_accuracies[-1] > 0.7:
    cNet.cNet.useC = True
# Out:
# Test set: Avg. loss: 2.3085, Accuracy: 1029/10000 (10%)
#
#
# Test set: Avg. loss: 2.3030, Accuracy: 1029/10000 (10%)
#
#
# Test set: Avg. loss: 2.2976, Accuracy: 1029/10000 (10%)
#
#
# Test set: Avg. loss: 2.2918, Accuracy: 1072/10000 (11%)
#
#
# Test set: Avg. loss: 2.2844, Accuracy: 1225/10000 (12%)
#
#
# Test set: Avg. loss: 2.2739, Accuracy: 1510/10000 (15%)
#
#
# Test set: Avg. loss: 2.2577, Accuracy: 2841/10000 (28%)
#
#
# Test set: Avg. loss: 2.2295, Accuracy: 3461/10000 (35%)
#
#
# Test set: Avg. loss: 2.1738, Accuracy: 3726/10000 (37%)
#
#
# Test set: Avg. loss: 2.0503, Accuracy: 4072/10000 (41%)
#
#
# Test set: Avg. loss: 1.8038, Accuracy: 4170/10000 (42%)
#
#
# Test set: Avg. loss: 1.4484, Accuracy: 5357/10000 (54%)
#
#
# Test set: Avg. loss: 1.1097, Accuracy: 6620/10000 (66%)
#
#
# Test set: Avg. loss: 0.8892, Accuracy: 7209/10000 (72%)
#
#
# Test set: Avg. loss: 0.7541, Accuracy: 7651/10000 (77%)
#
#
# Test set: Avg. loss: 0.6630, Accuracy: 7945/10000 (79%)
#
#
# Test set: Avg. loss: 0.5942, Accuracy: 8163/10000 (82%)
#
#
# Test set: Avg. loss: 0.5379, Accuracy: 8336/10000 (83%)
#
#
# Test set: Avg. loss: 0.4930, Accuracy: 8471/10000 (85%)
#
#
# Test set: Avg. loss: 0.4570, Accuracy: 8625/10000 (86%)
#
#
# Test set: Avg. loss: 0.4287, Accuracy: 8722/10000 (87%)
#
#
# Test set: Avg. loss: 0.4076, Accuracy: 8789/10000 (88%)
#
#
# Test set: Avg. loss: 0.3890, Accuracy: 8833/10000 (88%)
#
#
# Test set: Avg. loss: 0.3750, Accuracy: 8878/10000 (89%)
#
#
# Test set: Avg. loss: 0.3598, Accuracy: 8931/10000 (89%)
#
#
# Test set: Avg. loss: 0.3498, Accuracy: 8962/10000 (90%)
#
#
# Test set: Avg. loss: 0.3341, Accuracy: 9010/10000 (90%)
#
#
# Test set: Avg. loss: 0.3261, Accuracy: 9039/10000 (90%)
#
#
# Test set: Avg. loss: 0.3152, Accuracy: 9071/10000 (91%)
#
#
# Test set: Avg. loss: 0.3062, Accuracy: 9115/10000 (91%)
#
#
# Test set: Avg. loss: 0.2965, Accuracy: 9128/10000 (91%)
#
#
# Test set: Avg. loss: 0.2893, Accuracy: 9142/10000 (91%)
#
#
# Test set: Avg. loss: 0.2802, Accuracy: 9175/10000 (92%)
#
#
# Test set: Avg. loss: 0.2730, Accuracy: 9195/10000 (92%)
#
#
# Test set: Avg. loss: 0.2669, Accuracy: 9216/10000 (92%)
#
#
# Test set: Avg. loss: 0.2598, Accuracy: 9252/10000 (93%)
#
#
# Test set: Avg. loss: 0.2527, Accuracy: 9249/10000 (92%)
#
#
# Test set: Avg. loss: 0.2454, Accuracy: 9265/10000 (93%)
#
#
# Test set: Avg. loss: 0.2407, Accuracy: 9288/10000 (93%)
#
#
# Test set: Avg. loss: 0.2350, Accuracy: 9304/10000 (93%)
#
#
# Test set: Avg. loss: 0.2298, Accuracy: 9326/10000 (93%)
#
#
# Test set: Avg. loss: 0.2266, Accuracy: 9330/10000 (93%)
#
#
# Test set: Avg. loss: 0.2200, Accuracy: 9361/10000 (94%)
#
#
# Test set: Avg. loss: 0.2149, Accuracy: 9372/10000 (94%)
#
#
# Test set: Avg. loss: 0.2097, Accuracy: 9380/10000 (94%)
#
#
# Test set: Avg. loss: 0.2064, Accuracy: 9385/10000 (94%)
#
#
# Test set: Avg. loss: 0.2029, Accuracy: 9415/10000 (94%)
#
#
# Test set: Avg. loss: 0.1988, Accuracy: 9420/10000 (94%)
#
#
# Test set: Avg. loss: 0.1951, Accuracy: 9433/10000 (94%)
#
#
# Test set: Avg. loss: 0.1919, Accuracy: 9452/10000 (95%)
#
#
# Test set: Avg. loss: 0.1867, Accuracy: 9469/10000 (95%)
#
#
# Test set: Avg. loss: 0.1831, Accuracy: 9453/10000 (95%)
#
#
# Test set: Avg. loss: 0.1799, Accuracy: 9475/10000 (95%)
#
#
# Test set: Avg. loss: 0.1762, Accuracy: 9490/10000 (95%)
#
#
# Test set: Avg. loss: 0.1729, Accuracy: 9487/10000 (95%)
#
#
# Test set: Avg. loss: 0.1711, Accuracy: 9502/10000 (95%)
#
#
# Test set: Avg. loss: 0.1699, Accuracy: 9517/10000 (95%)
#
#
# Test set: Avg. loss: 0.1672, Accuracy: 9521/10000 (95%)
#
#
# Test set: Avg. loss: 0.1668, Accuracy: 9518/10000 (95%)
#
#
# Test set: Avg. loss: 0.1613, Accuracy: 9537/10000 (95%)
#
#
# Test set: Avg. loss: 0.1594, Accuracy: 9544/10000 (95%)
#
#
# Test set: Avg. loss: 0.1566, Accuracy: 9543/10000 (95%)
#
#
# Test set: Avg. loss: 0.1539, Accuracy: 9552/10000 (96%)
#
#
# Test set: Avg. loss: 0.1510, Accuracy: 9559/10000 (96%)
#
#
# Test set: Avg. loss: 0.1500, Accuracy: 9564/10000 (96%)
#
#
# Test set: Avg. loss: 0.1472, Accuracy: 9571/10000 (96%)
#
#
# Test set: Avg. loss: 0.1454, Accuracy: 9565/10000 (96%)
#
#
# Test set: Avg. loss: 0.1441, Accuracy: 9572/10000 (96%)
#
#
# Test set: Avg. loss: 0.1426, Accuracy: 9573/10000 (96%)
#
#
# Test set: Avg. loss: 0.1410, Accuracy: 9588/10000 (96%)
#
#
# Test set: Avg. loss: 0.1390, Accuracy: 9599/10000 (96%)
#
#
# Test set: Avg. loss: 0.1376, Accuracy: 9604/10000 (96%)
#
#
# Test set: Avg. loss: 0.1360, Accuracy: 9615/10000 (96%)
#
#
# Test set: Avg. loss: 0.1341, Accuracy: 9613/10000 (96%)
#
#
# Test set: Avg. loss: 0.1318, Accuracy: 9618/10000 (96%)
#
#
# Test set: Avg. loss: 0.1330, Accuracy: 9611/10000 (96%)
#
#
# Test set: Avg. loss: 0.1322, Accuracy: 9608/10000 (96%)
#
#
# Test set: Avg. loss: 0.1308, Accuracy: 9621/10000 (96%)
#
#
# Test set: Avg. loss: 0.1282, Accuracy: 9639/10000 (96%)
#
#
# Test set: Avg. loss: 0.1266, Accuracy: 9641/10000 (96%)
#
#
# Test set: Avg. loss: 0.1255, Accuracy: 9644/10000 (96%)
#
#
# Test set: Avg. loss: 0.1234, Accuracy: 9648/10000 (96%)
#
#
# Test set: Avg. loss: 0.1224, Accuracy: 9663/10000 (97%)
#
#
# Test set: Avg. loss: 0.1222, Accuracy: 9658/10000 (97%)
#
#
# Test set: Avg. loss: 0.1211, Accuracy: 9657/10000 (97%)
#
#
# Test set: Avg. loss: 0.1194, Accuracy: 9656/10000 (97%)
#
#
# Test set: Avg. loss: 0.1188, Accuracy: 9666/10000 (97%)
#
#
# Test set: Avg. loss: 0.1186, Accuracy: 9670/10000 (97%)
#
#
# Test set: Avg. loss: 0.1193, Accuracy: 9656/10000 (97%)
#
#
# Test set: Avg. loss: 0.1188, Accuracy: 9658/10000 (97%)
#
#
# Test set: Avg. loss: 0.1168, Accuracy: 9674/10000 (97%)
#
#
# Test set: Avg. loss: 0.1142, Accuracy: 9676/10000 (97%)
#
#
# Test set: Avg. loss: 0.1142, Accuracy: 9681/10000 (97%)
#
#
# Test set: Avg. loss: 0.1122, Accuracy: 9675/10000 (97%)
#
#
# Test set: Avg. loss: 0.1109, Accuracy: 9691/10000 (97%)
#
#
# Test set: Avg. loss: 0.1112, Accuracy: 9691/10000 (97%)
#
#
# Test set: Avg. loss: 0.1114, Accuracy: 9686/10000 (97%)
#
#
# Test set: Avg. loss: 0.1113, Accuracy: 9695/10000 (97%)
#
#
# Test set: Avg. loss: 0.1106, Accuracy: 9687/10000 (97%)
#
#
# Test set: Avg. loss: 0.1096, Accuracy: 9698/10000 (97%)
#
#
# Test set: Avg. loss: 0.1080, Accuracy: 9703/10000 (97%)

# %%
Test set: Avg. loss: 0.1158, Accuracy: 9649/10000 (96%) # no warm up
Test set: Avg. loss: 0.1035, Accuracy: 9680/10000 (97%) # 0.5
Test set: Avg. loss: 0.1080, Accuracy: 9703/10000 (97%) # 0.7
